# %%
# %reload_ext autoreload
# %autoreload 2

from pathlib import Path
from mgclass import analysis, MusicGenreDataset, networks
from mgclass.utils import *
from mgclass.training import TrainingRun
from torch import optim

# %%
dry_run = False

# %%
def run_experiment(model, win_size, batch_size=64, optimizer=None):

    if optimizer is None:
        optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

    run = TrainingRun(dataset,
                      model,
                      epochs=100,
                      batch_size=batch_size,
                      dry_run=dry_run,
                      repeat_count=100,
                      patience=5,
                      save_path=Path(f"./out/{type(model).__name__}-{win_size}.pt"),
                      optimizer=optimizer)

    run.start(silent=True)
    run.test()
    run.plot(f"{type(model).__name__} - {win_size // 16}ms resolution", additional_info=f"win_length: {win_size}")

# %% [markdown]
# ## Higher Temporal Resolution

# %%
dataset = MusicGenreDataset(
        data_dir=Path("/home/georg/Music/ADL/"),
        preprocess=create_spectrogram(win_length=2048),
        file_transform=mp3_to_wav_location,
        playlist_to_genre=sample_playlist_to_genre,
        transform=create_crop((128, 128)),
        dry_run = dry_run
)

analysis.summarize_dataset(dataset)
# Out:
# Using genre from playlist source
# Clamping dataset to 160 songs per class. Removing 279 songs.
# Preprocessing complete
# Creating dataset:   0%|          | 0/1280 [00:00<?, ?it/s]
# Dataset creation finished in: 100.9037 seconds

# %% [markdown]
# ### MusicRecNet

# %%
music_rec_net = networks.MusicRecNet(dataset.num_classes)
run_experiment(music_rec_net, batch_size=128, win_size=1024)
# Out:
# Epoch   1/100:   0%|          | 0.00/100 [00:00<?, ?epochs/s]
# Training for 100 epochs
# Early stopped at epoch 42
# Training finished in: 2068.5278 seconds

# %% [markdown]
# ### Resnet

# %%
resnet18 = networks.ResNet(dataset.num_classes)
run_experiment(resnet18, batch_size=64, win_size=1024, optimizer=optim.SGD(resnet18.parameters(), lr=0.001, momentum=0.9, weight_decay=0.0005))
# Out:
# Epoch   1/100:   0%|          | 0.00/100 [00:00<?, ?epochs/s]
# Training for 100 epochs
# Training finished in: 105.0543 seconds
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 2
#       1 resnet18 = networks.ResNet(dataset.num_classes)
# ----> 2 run_experiment(resnet18, batch_size=64, win_size=1024, optimizer=optim.SGD(resnet18.parameters(), lr=0.001, momentum=0.9, weight_decay=0.0005))
#
# Cell In[3], line 16, in run_experiment(model, win_size, batch_size, optimizer)
#       4     optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)
#       6 run = TrainingRun(dataset,
#       7                   model,
#       8                   epochs=100,
#    (...)
#      13                   save_path=Path(f"./out/{type(model).__name__}-{win_size}.pt"),
#      14                   optimizer=optimizer)
# ---> 16 run.start(silent=True)
#      17 run.test()
#      18 run.plot(f"{type(model).__name__} - {win_size // 16}ms resolution", additional_info=f"win_length: {win_size}")
#
# File ~/git/music-genre-classification/mgclass/training.py:100, in TrainingRun.start(self, silent)
#      97 self.already_ran = True
#      99 with Timer("Training"):
# --> 100     self._train(silent)
#     102 print("")
#
# File ~/git/music-genre-classification/mgclass/training.py:207, in TrainingRun._train(self, silent)
#     203 self.optimizer.step()
#     205 self.model.train(False)
# --> 207 batch_losses.append(loss.item())
#     208 train_acc.update(outputs, label)
#     210 pbar.update(bar_step)
#
# KeyboardInterrupt:

# %% [markdown]
# ### MgcNet

# %%
my_net = networks.MgcNet(dataset.num_classes)
run_experiment(my_net, batch_size=128, win_size=1024)

# %% [markdown]
# ## Lower Temporal Resolution

# %%
dataset = MusicGenreDataset(
        data_dir=Path("/home/georg/Music/ADL/"),
        preprocess=create_spectrogram(win_length=2048),
        file_transform=mp3_to_wav_location,
        playlist_to_genre=sample_playlist_to_genre,
        transform=create_crop((128, 128)),
        dry_run = dry_run
)

analysis.summarize_dataset(dataset)

# %% [markdown]
# ### MusicRecNet

# %%
music_rec_net = networks.MusicRecNet(dataset.num_classes)
run_experiment(music_rec_net, batch_size=128, win_size=2048)

# %% [markdown]
# ### Resnet

# %%
resnet18 = networks.ResNet(dataset.num_classes)
run_experiment(resnet18, batch_size=64, win_size=2048, optimizer=optim.SGD(resnet18.parameters(), lr=0.001, momentum=0.9, weight_decay=0.0005))

# %% [markdown]
# ### MgcNet

# %%
my_net = networks.MgcNet(dataset.num_classes)
run_experiment(my_net, batch_size=128, win_size=2048)
